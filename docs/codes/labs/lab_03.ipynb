# %% [markdown]
# <a href="https://colab.research.google.com/github/fralfaro/MAT306/blob/main/docs/labs/lab_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
#
# # MAT306 - Laboratorio N°03

# %% [markdown]
# **Objetivo**: Aplicar técnicas avanzadas de manipulación y análisis de datos con pandas sobre un conjunto real de datos de contenido de Netflix, reforzando buenas prácticas y métodos eficientes sin recurrir a `groupby`, `merge`, `pivot`, ni `join`.
#
#
#
# **Dataset**:
#
# Trabajaremos con el archivo `netflix_titles.csv`, que contiene información sobre los títulos disponibles en la plataforma Netflix hasta el año 2021.
#
# | Variable       | Clase     | Descripción                                                                 |
# |----------------|-----------|------------------------------------------------------------------------------|
# | show_id        | caracter  | Identificador único del título en el catálogo de Netflix.                   |
# | type           | caracter  | Tipo de contenido: 'Movie' o 'TV Show'.                                     |
# | title          | caracter  | Título del contenido.                                                       |
# | director       | caracter  | Nombre del director (puede ser nulo).                                       |
# | cast           | caracter  | Lista de actores principales (puede ser nulo).                              |
# | country        | caracter  | País o países donde se produjo el contenido.                                |
# | date_added     | fecha     | Fecha en la que el título fue agregado al catálogo de Netflix.              |
# | release_year   | entero    | Año de lanzamiento original del título.                                     |
# | rating         | caracter  | Clasificación por edad (por ejemplo: 'PG-13', 'TV-MA').                      |
# | duration       | caracter  | Duración del contenido (minutos o número de temporadas para series).        |
# | listed_in      | caracter  | Categorías o géneros en los que está clasificado el contenido.              |
# | description    | caracter  | Breve sinopsis del contenido.                                               |

# %%
import pandas as pd

# Cargar datos
df = pd.read_csv('https://raw.githubusercontent.com/fralfaro/MAT306/main/docs/labs/data/netflix_titles.csv')
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# 4  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...
# 3  Feuds, flirtations and toilet talk go down amo...
# 4  In a city of coaching centers known to train I...

# %% [markdown]
# ### Parte 1: Limpieza y preparación
#
# 1. Revisar y describir el dataset:
#
#    * ¿Cuántas filas y columnas tiene?
#    * ¿Qué tipos de datos hay?
#    * ¿Cuántos valores nulos hay por columna?
#
# 2. Transformar la columna `date_added` a tipo fecha.
#
# 3. Crear columnas auxiliares con `assign`:
#
#    * Año (`year_added`)
#    * Mes (`month_added`)

# %% [markdown]
# #### 1. Revisar y describir el dataset:

# %%
display(f'El dataframe tiene {df.shape[0]} filas y {df.shape[1]} columnas')
# Out:
# 'El dataframe tiene 8807 filas y 12 columnas'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %% [markdown]
# Hay datos de tipo objeto y int64.

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %% [markdown]
# La cantidad de NaN por columna se muestra en el codigo inmediatamente anterior

# %% [markdown]
# #### 2. Transformar la columna date_added a tipo fecha.

# %%
display(df['date_added'].head())
display(df['date_added'].tail())
# Out:
# 0    September 25, 2021
# 1    September 24, 2021
# 2    September 24, 2021
# 3    September 24, 2021
# 4    September 24, 2021
# Name: date_added, dtype: object
# 8802    November 20, 2019
# 8803         July 1, 2019
# 8804     November 1, 2019
# 8805     January 11, 2020
# 8806        March 2, 2019
# Name: date_added, dtype: object

# %% [markdown]
# El formato de fecha actual no es compatible directamente con el metodo pd.to_datetime. Para salvarguar esto hay que fijar uno explicitamente.

# %%
df['date_added'] = pd.to_datetime(df['date_added'], format='%B %d, %Y', errors='coerce')
display(df['date_added'])
# Out:
# 0      2021-09-25
# 1      2021-09-24
# 2      2021-09-24
# 3      2021-09-24
# 4      2021-09-24
#           ...
# 8802   2019-11-20
# 8803   2019-07-01
# 8804   2019-11-01
# 8805   2020-01-11
# 8806   2019-03-02
# Name: date_added, Length: 8807, dtype: datetime64[ns]

# %% [markdown]
# #### 3. Crear columnas auxiliares con `assign`:

# %%
df = df.assign(
    year_added=df['date_added'].dt.year.astype('Int64'),
    month_added=df['date_added'].dt.month.astype('Int64')
)
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#   date_added  release_year rating   duration  \
# 0 2021-09-25          2020  PG-13     90 min
# 1 2021-09-24          2021  TV-MA  2 Seasons
# 2 2021-09-24          2021  TV-MA   1 Season
# 3 2021-09-24          2021  TV-MA   1 Season
# 4 2021-09-24          2021  TV-MA  2 Seasons
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description  year_added  month_added
# 0  As her father nears the end of his life, filmm...        2021            9
# 1  After crossing paths at a party, a Cape Town t...        2021            9
# 2  To protect his family from a powerful drug lor...        2021            9
# 3  Feuds, flirtations and toilet talk go down amo...        2021            9
# 4  In a city of coaching centers known to train I...        2021            9

# %% [markdown]
# ### Parte 2: Técnicas avanzadas de pandas
#
# 4. Utilizar `.loc` para seleccionar películas (`type == 'Movie'`) que fueron agregadas después del año 2018.
#
# 5. Utilizar `str.contains()` y `str.extract()`:
#
#    * Filtrar títulos que contienen la palabra 'love' (sin distinguir mayúsculas/minúsculas).
#    * Extraer la duración en minutos para las películas desde la columna `duration`.
#
# 6. Aplicar `explode()` sobre la columna `listed_in` para obtener una fila por cada género.
#
# 7. Obtener un top 10 de géneros más frecuentes utilizando `value_counts()`.
#
# 8. Aplicar `where()` y `mask()` para marcar las películas de más de 120 minutos como contenido largo en una nueva columna.
#
# 9. Utilizar `.loc` para filtrar películas que cumplen con:
#
#    * Más de 100 minutos de duración.
#    * Rating igual a `'R'`.
#    * País igual a `'United States'`.
#
# 10. Utilizar `.style` para formatear visualmente el top 10 de películas más largas.

# %% [markdown]
# #### 4. Utilizar .loc para seleccionar películas (type == 'Movie') que fueron agregadas después del año 2018.

# %%
peliculas_agregadas_despues_2018 = df.loc[(df['type'] == 'Movie') & (df['date_added'].dt.year >= 2018)]
display(peliculas_agregadas_despues_2018)
# Out:
#      show_id   type                             title  \
# 0         s1  Movie              Dick Johnson Is Dead
# 6         s7  Movie  My Little Pony: A New Generation
# 7         s8  Movie                           Sankofa
# 9        s10  Movie                      The Starling
# 12       s13  Movie                      Je Suis Karl
# ...      ...    ...                               ...
# 8799   s8800  Movie                             Zenda
# 8802   s8803  Movie                            Zodiac
# 8804   s8805  Movie                        Zombieland
# 8805   s8806  Movie                              Zoom
# 8806   s8807  Movie                            Zubaan
#
#                            director  \
# 0                   Kirsten Johnson
# 6     Robert Cullen, José Luis Ucha
# 7                      Haile Gerima
# 9                    Theodore Melfi
# 12              Christian Schwochow
# ...                             ...
# 8799                 Avadhoot Gupte
# 8802                  David Fincher
# 8804                Ruben Fleischer
# 8805                   Peter Hewitt
# 8806                    Mozez Singh
#
#                                                    cast  \
# 0                                                   NaN
# 6     Vanessa Hudgens, Kimiko Glenn, James Marsden, ...
# 7     Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 9     Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 12    Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
# ...                                                 ...
# 8799  Santosh Juvekar, Siddharth Chandekar, Sachit P...
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
#
#                                                 country date_added  \
# 0                                         United States 2021-09-25
# 6                                                   NaN 2021-09-24
# 7     United States, Ghana, Burkina Faso, United Kin... 2021-09-24
# 9                                         United States 2021-09-24
# 12                              Germany, Czech Republic 2021-09-23
# ...                                                 ...        ...
# 8799                                              India 2018-02-15
# 8802                                      United States 2019-11-20
# 8804                                      United States 2019-11-01
# 8805                                      United States 2020-01-11
# 8806                                              India 2019-03-02
#
#       release_year rating duration  \
# 0             2020  PG-13   90 min
# 6             2021     PG   91 min
# 7             1993  TV-MA  125 min
# 9             2021  PG-13  104 min
# 12            2021  TV-MA  127 min
# ...            ...    ...      ...
# 8799          2009  TV-14  120 min
# 8802          2007      R  158 min
# 8804          2009      R   88 min
# 8805          2006     PG   88 min
# 8806          2015  TV-14  111 min
#
#                                              listed_in  \
# 0                                        Documentaries
# 6                             Children & Family Movies
# 7     Dramas, Independent Movies, International Movies
# 9                                     Comedies, Dramas
# 12                        Dramas, International Movies
# ...                                                ...
# 8799                      Dramas, International Movies
# 8802                    Cult Movies, Dramas, Thrillers
# 8804                           Comedies, Horror Movies
# 8805                Children & Family Movies, Comedies
# 8806    Dramas, International Movies, Music & Musicals
#
#                                             description  year_added  \
# 0     As her father nears the end of his life, filmm...        2021
# 6     Equestria's divided. But a bright-eyed hero be...        2021
# 7     On a photo shoot in Ghana, an American model s...        2021
# 9     A woman adjusting to life after a loss contend...        2021
# 12    After most of her family is murdered in a terr...        2021
# ...                                                 ...         ...
# 8799  A change in the leadership of a political part...        2018
# 8802  A political cartoonist, a crime reporter and a...        2019
# 8804  Looking to survive in a world taken over by zo...        2019
# 8805  Dragged from civilian life, a former superhero...        2020
# 8806  A scrappy but poor boy worms his way into a ty...        2019
#
#       month_added
# 0               9
# 6               9
# 7               9
# 9               9
# 12              9
# ...           ...
# 8799            2
# 8802           11
# 8804           11
# 8805            1
# 8806            3
#
# [4938 rows x 14 columns]

# %% [markdown]
# #### 5. Utilizar str.contains() y str.extract():

# %% [markdown]
# Fltrar las peliculas cuyo titulo contengan la palabra love

# %%
titulo_peliculas_con_love = df[df['title'].str.contains('love', case=False)]
display(titulo_peliculas_con_love)
# Out:
#      show_id     type                           title  \
# 25       s26  TV Show            Love on the Spectrum
# 158     s159    Movie         Love Don't Cost a Thing
# 159     s160    Movie                  Love in a Puff
# 206     s207    Movie       LSD: Love, Sex Aur Dhokha
# 227     s228    Movie                     Really Love
# ...      ...      ...                             ...
# 8567   s8568  TV Show  The Year of Happiness and Love
# 8575   s8576  TV Show                 This Is My Love
# 8649   s8650    Movie           Two Lovers and a Bear
# 8721   s8722  TV Show                   What Is Love?
# 8725   s8726    Movie            What's Up With Love?
#
#                        director  \
# 25                          NaN
# 158                   Troy Byer
# 159              Pang Ho-cheung
# 206            Dibakar Banerjee
# 227       Angel Kristi Williams
# ...                         ...
# 8567                        NaN
# 8575                        NaN
# 8649                 Kim Nguyen
# 8721                        NaN
# 8725  Rudy Soedjarwo, Riri Riza
#
#                                                    cast        country  \
# 25                                     Brooke Satchwell      Australia
# 158   Nick Cannon, Christina Milian, Kenan Thompson,...  United States
# 159   Miriam Chin Wah Yeung, Shawn Yue, Singh Hartih...      Hong Kong
# 206   Nushrat Bharucha, Anshuman Jha, Neha Chauhan, ...          India
# 227   Kofi Siriboe, Yootha Wong-Loi-Sing, Michael Ea...  United States
# ...                                                 ...            ...
# 8567  Amber Kuo, James Wen, Weber Yang, Sonia Sui, N...         Taiwan
# 8575  Jin-mo Joo, Sa-rang Kim, Junior, Ja-in Lee, Su...    South Korea
# 8649  Dane DeHaan, Tatiana Maslany, Gordon Pinsent, ...         Canada
# 8721  Chris Wu, Jade Chou, Duncan Lai, King Chin, Ki...         Taiwan
# 8725  Dian Sastrowardoyo, Nicholas Saputra, Ladya Ch...      Indonesia
#
#      date_added  release_year rating   duration  \
# 25   2021-09-21          2021  TV-14  2 Seasons
# 158  2021-09-01          2003  PG-13    101 min
# 159  2021-09-01          2010  TV-MA    103 min
# 206  2021-08-27          2010  TV-MA    112 min
# 227  2021-08-25          2020  TV-MA     95 min
# ...         ...           ...    ...        ...
# 8567 2016-09-01          2009  TV-PG   1 Season
# 8575 2017-05-22          2015  TV-14   1 Season
# 8649 2017-05-02          2016      R     95 min
# 8721 2017-01-01          2012  TV-14   1 Season
# 8725 2018-12-08          2002      R    110 min
#
#                                               listed_in  \
# 25       Docuseries, International TV Shows, Reality TV
# 158                           Comedies, Romantic Movies
# 159              Comedies, Dramas, International Movies
# 206    Dramas, Independent Movies, International Movies
# 227         Dramas, Independent Movies, Romantic Movies
# ...                                                 ...
# 8567  International TV Shows, Romantic TV Shows, TV ...
# 8575  International TV Shows, Korean TV Shows, Roman...
# 8649        Dramas, Independent Movies, Romantic Movies
# 8721  International TV Shows, Romantic TV Shows, TV ...
# 8725      Dramas, International Movies, Romantic Movies
#
#                                             description  year_added  \
# 25    Finding love can be hard for anyone. For young...        2021
# 158   A nerdy teen tries to make himself cool by ass...        2021
# 159   When the Hong Kong government enacts a ban on ...        2021
# 206   This provocative drama examines how the voyeur...        2021
# 227   A rising Black painter tries to break into a c...        2021
# ...                                                 ...         ...
# 8567  Jiang Chen-bo is a loser without prospects for...        2016
# 8575  A renowned actor who is still pining over the ...        2017
# 8649  A troubled couple living near the North Pole b...        2017
# 8721  A 32-year-old romantic looking for a long-term...        2017
# 8725  A popular high school girl strains her relatio...        2018
#
#       month_added
# 25              9
# 158             9
# 159             9
# 206             8
# 227             8
# ...           ...
# 8567            9
# 8575            5
# 8649            5
# 8721            1
# 8725           12
#
# [196 rows x 14 columns]

# %% [markdown]
# Extraer la duracion en minutos para las peliculas

# %%
duracion_minutos_peliculas = df['duration'].str.extract(r'(\d+) min').astype('Int64')
df = df.assign(duracion_minutos_peliculas=duracion_minutos_peliculas)
display(df.head())
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#   date_added  release_year rating   duration  \
# 0 2021-09-25          2020  PG-13     90 min
# 1 2021-09-24          2021  TV-MA  2 Seasons
# 2 2021-09-24          2021  TV-MA   1 Season
# 3 2021-09-24          2021  TV-MA   1 Season
# 4 2021-09-24          2021  TV-MA  2 Seasons
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description  year_added  month_added  \
# 0  As her father nears the end of his life, filmm...        2021            9
# 1  After crossing paths at a party, a Cape Town t...        2021            9
# 2  To protect his family from a powerful drug lor...        2021            9
# 3  Feuds, flirtations and toilet talk go down amo...        2021            9
# 4  In a city of coaching centers known to train I...        2021            9
#
#    duracion_minutos_peliculas
# 0                          90
# 1                        <NA>
# 2                        <NA>
# 3                        <NA>
# 4                        <NA>

# %% [markdown]
# #### 6. Aplicar `explode()` sobre la columna `listed_in` para obtener una fila por cada género.

# %%
df['generos']= df['listed_in'].str.split(', ')
df = df.explode('generos')
display(df.head())
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
# 1      s2  TV Show         Blood & Water              NaN
# 1      s2  TV Show         Blood & Water              NaN
# 2      s3  TV Show             Ganglands  Julien Leclercq
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
#
#   date_added  release_year rating   duration  \
# 0 2021-09-25          2020  PG-13     90 min
# 1 2021-09-24          2021  TV-MA  2 Seasons
# 1 2021-09-24          2021  TV-MA  2 Seasons
# 1 2021-09-24          2021  TV-MA  2 Seasons
# 2 2021-09-24          2021  TV-MA   1 Season
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
#
#                                          description  year_added  month_added  \
# 0  As her father nears the end of his life, filmm...        2021            9
# 1  After crossing paths at a party, a Cape Town t...        2021            9
# 1  After crossing paths at a party, a Cape Town t...        2021            9
# 1  After crossing paths at a party, a Cape Town t...        2021            9
# 2  To protect his family from a powerful drug lor...        2021            9
#
#    duracion_minutos_peliculas                 generos
# 0                          90           Documentaries
# 1                        <NA>  International TV Shows
# 1                        <NA>               TV Dramas
# 1                        <NA>            TV Mysteries
# 2                        <NA>          Crime TV Shows

# %% [markdown]
# #### 7. Obtener un top 10 de géneros más frecuentes utilizando value_counts().

# %%
top_10_generos = df['generos'].value_counts().head(10)
display(top_10_generos)
# Out:
# generos
# International Movies        2752
# Dramas                      2427
# Comedies                    1674
# International TV Shows      1351
# Documentaries                869
# Action & Adventure           859
# TV Dramas                    763
# Independent Movies           756
# Children & Family Movies     641
# Romantic Movies              616
# Name: count, dtype: int64

# %% [markdown]
# #### 8. Aplicar where() y mask() para marcar las películas de más de 120 minutos como contenido largo en una nueva columna.

# %%
df['extension_contenido'] = 'no_es_pelicula'
df['extension_contenido'] = df['extension_contenido'].where(df['type'] == 'Movie', other='no_es_pelicula')
df['extension_contenido'] = df['extension_contenido'].mask(df['duracion_minutos_peliculas'] < 120, other='contenido_corto')
df['extension_contenido'] = df['extension_contenido'].mask(df['duracion_minutos_peliculas'] >= 120, other='contenido_largo')

display(df[['type', 'duracion_minutos_peliculas', 'extension_contenido']].head())
# Out:
#       type  duracion_minutos_peliculas extension_contenido
# 0    Movie                          90     contenido_corto
# 1  TV Show                        <NA>     contenido_largo
# 1  TV Show                        <NA>     contenido_largo
# 1  TV Show                        <NA>     contenido_largo
# 2  TV Show                        <NA>     contenido_largo

# %% [markdown]
#  #### 9. Utilizar `.loc` para filtrar películas que cumplen con:
#
#    * Más de 100 minutos de duración.
#    * Rating igual a `'R'`.
#    * País igual a `'United States'`.

# %%
peliculas_filtradas = df.loc[
    (df['type']=='Movie') &
    (df['duracion_minutos_peliculas'] > 100) &
    (df['rating']== 'R') &
    (df['country'] == 'United States')
]
display(peliculas_filtradas)
# Out:
#      show_id   type                        title               director  \
# 48       s49  Movie                 Training Day          Antoine Fuqua
# 48       s49  Movie                 Training Day          Antoine Fuqua
# 81       s82  Movie                         Kate  Cedric Nicolas-Troyan
# 131     s132  Movie  Blade Runner: The Final Cut           Ridley Scott
# 131     s132  Movie  Blade Runner: The Final Cut           Ridley Scott
# ...      ...    ...                          ...                    ...
# 8754   s8755  Movie                       Wolves        Bart Freundlich
# 8754   s8755  Movie                       Wolves        Bart Freundlich
# 8802   s8803  Movie                       Zodiac          David Fincher
# 8802   s8803  Movie                       Zodiac          David Fincher
# 8802   s8803  Movie                       Zodiac          David Fincher
#
#                                                    cast        country  \
# 48    Denzel Washington, Ethan Hawke, Scott Glenn, T...  United States
# 48    Denzel Washington, Ethan Hawke, Scott Glenn, T...  United States
# 81    Mary Elizabeth Winstead, Jun Kunimura, Woody H...  United States
# 131   Harrison Ford, Rutger Hauer, Sean Young, Edwar...  United States
# 131   Harrison Ford, Rutger Hauer, Sean Young, Edwar...  United States
# ...                                                 ...            ...
# 8754  Michael Shannon, Carla Gugino, Taylor John Smi...  United States
# 8754  Michael Shannon, Carla Gugino, Taylor John Smi...  United States
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
#
#      date_added  release_year rating duration  \
# 48   2021-09-16          2001      R  122 min
# 48   2021-09-16          2001      R  122 min
# 81   2021-09-10          2021      R  106 min
# 131  2021-09-01          1982      R  117 min
# 131  2021-09-01          1982      R  117 min
# ...         ...           ...    ...      ...
# 8754 2019-03-29          2016      R  109 min
# 8754 2019-03-29          2016      R  109 min
# 8802 2019-11-20          2007      R  158 min
# 8802 2019-11-20          2007      R  158 min
# 8802 2019-11-20          2007      R  158 min
#
#                                             listed_in  \
# 48                                  Dramas, Thrillers
# 48                                  Dramas, Thrillers
# 81                                 Action & Adventure
# 131   Action & Adventure, Classic Movies, Cult Movies
# 131   Action & Adventure, Classic Movies, Cult Movies
# ...                                               ...
# 8754        Dramas, Independent Movies, Sports Movies
# 8754        Dramas, Independent Movies, Sports Movies
# 8802                   Cult Movies, Dramas, Thrillers
# 8802                   Cult Movies, Dramas, Thrillers
# 8802                   Cult Movies, Dramas, Thrillers
#
#                                             description  year_added  \
# 48    A rookie cop with one day to prove himself to ...        2021
# 48    A rookie cop with one day to prove himself to ...        2021
# 81    Slipped a fatal poison on her final job, a rut...        2021
# 131   In a smog-choked dystopian Los Angeles, blade ...        2021
# 131   In a smog-choked dystopian Los Angeles, blade ...        2021
# ...                                                 ...         ...
# 8754  A promising high school basketball player has ...        2019
# 8754  A promising high school basketball player has ...        2019
# 8802  A political cartoonist, a crime reporter and a...        2019
# 8802  A political cartoonist, a crime reporter and a...        2019
# 8802  A political cartoonist, a crime reporter and a...        2019
#
#       month_added  duracion_minutos_peliculas             generos  \
# 48              9                         122              Dramas
# 48              9                         122           Thrillers
# 81              9                         106  Action & Adventure
# 131             9                         117  Action & Adventure
# 131             9                         117      Classic Movies
# ...           ...                         ...                 ...
# 8754            3                         109  Independent Movies
# 8754            3                         109       Sports Movies
# 8802           11                         158         Cult Movies
# 8802           11                         158              Dramas
# 8802           11                         158           Thrillers
#
#      extension_contenido
# 48       contenido_largo
# 48       contenido_largo
# 81       contenido_corto
# 131      contenido_corto
# 131      contenido_corto
# ...                  ...
# 8754     contenido_corto
# 8754     contenido_corto
# 8802     contenido_largo
# 8802     contenido_largo
# 8802     contenido_largo
#
# [469 rows x 17 columns]

# %% [markdown]
# #### 10.Utilizar .style para formatear visualmente el top 10 de películas más largas.

# %%
top_10_peliculas_largas = df.loc[df['type'] == 'Movie'].sort_values(by='duracion_minutos_peliculas', ascending=False).head(10).reset_index(drop=True)
styled_top_10 = top_10_peliculas_largas.style.background_gradient(subset=['duracion_minutos_peliculas'], cmap='Blues')
display(styled_top_10)
# Out:
# <style type="text/css">
# #T_0ed22_row0_col14, #T_0ed22_row1_col14, #T_0ed22_row2_col14 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_0ed22_row3_col14 {
#   background-color: #74b3d8;
#   color: #000000;
# }
# #T_0ed22_row4_col14, #T_0ed22_row5_col14, #T_0ed22_row6_col14 {
#   background-color: #cde0f1;
#   color: #000000;
# }
# #T_0ed22_row7_col14, #T_0ed22_row8_col14, #T_0ed22_row9_col14 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_0ed22" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0ed22_level0_col0" class="col_heading level0 col0" >show_id</th>
#       <th id="T_0ed22_level0_col1" class="col_heading level0 col1" >type</th>
#       <th id="T_0ed22_level0_col2" class="col_heading level0 col2" >title</th>
#       <th id="T_0ed22_level0_col3" class="col_heading level0 col3" >director</th>
#       <th id="T_0ed22_level0_col4" class="col_heading level0 col4" >cast</th>
#       <th id="T_0ed22_level0_col5" class="col_heading level0 col5" >country</th>
#       <th id="T_0ed22_level0_col6" class="col_heading level0 col6" >date_added</th>
#       <th id="T_0ed22_level0_col7" class="col_heading level0 col7" >release_year</th>
#       <th id="T_0ed22_level0_col8" class="col_heading level0 col8" >rating</th>
#       <th id="T_0ed22_level0_col9" class="col_heading level0 col9" >duration</th>
#       <th id="T_0ed22_level0_col10" class="col_heading level0 col10" >listed_in</th>
#       <th id="T_0ed22_level0_col11" class="col_heading level0 col11" >description</th>
#       <th id="T_0ed22_level0_col12" class="col_heading level0 col12" >year_added</th>
#       <th id="T_0ed22_level0_col13" class="col_heading level0 col13" >month_added</th>
#       <th id="T_0ed22_level0_col14" class="col_heading level0 col14" >duracion_minutos_peliculas</th>
#       <th id="T_0ed22_level0_col15" class="col_heading level0 col15" >generos</th>
#       <th id="T_0ed22_level0_col16" class="col_heading level0 col16" >extension_contenido</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0ed22_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0ed22_row0_col0" class="data row0 col0" >s4254</td>
#       <td id="T_0ed22_row0_col1" class="data row0 col1" >Movie</td>
#       <td id="T_0ed22_row0_col2" class="data row0 col2" >Black Mirror: Bandersnatch</td>
#       <td id="T_0ed22_row0_col3" class="data row0 col3" >nan</td>
#       <td id="T_0ed22_row0_col4" class="data row0 col4" >Fionn Whitehead, Will Poulter, Craig Parkinson, Alice Lowe, Asim Chaudhry</td>
#       <td id="T_0ed22_row0_col5" class="data row0 col5" >United States</td>
#       <td id="T_0ed22_row0_col6" class="data row0 col6" >2018-12-28 00:00:00</td>
#       <td id="T_0ed22_row0_col7" class="data row0 col7" >2018</td>
#       <td id="T_0ed22_row0_col8" class="data row0 col8" >TV-MA</td>
#       <td id="T_0ed22_row0_col9" class="data row0 col9" >312 min</td>
#       <td id="T_0ed22_row0_col10" class="data row0 col10" >Dramas, International Movies, Sci-Fi & Fantasy</td>
#       <td id="T_0ed22_row0_col11" class="data row0 col11" >In 1984, a young programmer begins to question reality as he adapts a dark fantasy novel into a video game. A mind-bending tale with multiple endings.</td>
#       <td id="T_0ed22_row0_col12" class="data row0 col12" >2018</td>
#       <td id="T_0ed22_row0_col13" class="data row0 col13" >12</td>
#       <td id="T_0ed22_row0_col14" class="data row0 col14" >312</td>
#       <td id="T_0ed22_row0_col15" class="data row0 col15" >International Movies</td>
#       <td id="T_0ed22_row0_col16" class="data row0 col16" >contenido_largo</td>
#     </tr>
#     <tr>
#       <th id="T_0ed22_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0ed22_row1_col0" class="data row1 col0" >s4254</td>
#       <td id="T_0ed22_row1_col1" class="data row1 col1" >Movie</td>
#       <td id="T_0ed22_row1_col2" class="data row1 col2" >Black Mirror: Bandersnatch</td>
#       <td id="T_0ed22_row1_col3" class="data row1 col3" >nan</td>
#       <td id="T_0ed22_row1_col4" class="data row1 col4" >Fionn Whitehead, Will Poulter, Craig Parkinson, Alice Lowe, Asim Chaudhry</td>
#       <td id="T_0ed22_row1_col5" class="data row1 col5" >United States</td>
#       <td id="T_0ed22_row1_col6" class="data row1 col6" >2018-12-28 00:00:00</td>
#       <td id="T_0ed22_row1_col7" class="data row1 col7" >2018</td>
#       <td id="T_0ed22_row1_col8" class="data row1 col8" >TV-MA</td>
#       <td id="T_0ed22_row1_col9" class="data row1 col9" >312 min</td>
#       <td id="T_0ed22_row1_col10" class="data row1 col10" >Dramas, International Movies, Sci-Fi & Fantasy</td>
#       <td id="T_0ed22_row1_col11" class="data row1 col11" >In 1984, a young programmer begins to question reality as he adapts a dark fantasy novel into a video game. A mind-bending tale with multiple endings.</td>
#       <td id="T_0ed22_row1_col12" class="data row1 col12" >2018</td>
#       <td id="T_0ed22_row1_col13" class="data row1 col13" >12</td>
#       <td id="T_0ed22_row1_col14" class="data row1 col14" >312</td>
#       <td id="T_0ed22_row1_col15" class="data row1 col15" >Dramas</td>
#       <td id="T_0ed22_row1_col16" class="data row1 col16" >contenido_largo</td>
#     </tr>
#     <tr>
#       <th id="T_0ed22_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0ed22_row2_col0" class="data row2 col0" >s4254</td>
#       <td id="T_0ed22_row2_col1" class="data row2 col1" >Movie</td>
#       <td id="T_0ed22_row2_col2" class="data row2 col2" >Black Mirror: Bandersnatch</td>
#       <td id="T_0ed22_row2_col3" class="data row2 col3" >nan</td>
#       <td id="T_0ed22_row2_col4" class="data row2 col4" >Fionn Whitehead, Will Poulter, Craig Parkinson, Alice Lowe, Asim Chaudhry</td>
#       <td id="T_0ed22_row2_col5" class="data row2 col5" >United States</td>
#       <td id="T_0ed22_row2_col6" class="data row2 col6" >2018-12-28 00:00:00</td>
#       <td id="T_0ed22_row2_col7" class="data row2 col7" >2018</td>
#       <td id="T_0ed22_row2_col8" class="data row2 col8" >TV-MA</td>
#       <td id="T_0ed22_row2_col9" class="data row2 col9" >312 min</td>
#       <td id="T_0ed22_row2_col10" class="data row2 col10" >Dramas, International Movies, Sci-Fi & Fantasy</td>
#       <td id="T_0ed22_row2_col11" class="data row2 col11" >In 1984, a young programmer begins to question reality as he adapts a dark fantasy novel into a video game. A mind-bending tale with multiple endings.</td>
#       <td id="T_0ed22_row2_col12" class="data row2 col12" >2018</td>
#       <td id="T_0ed22_row2_col13" class="data row2 col13" >12</td>
#       <td id="T_0ed22_row2_col14" class="data row2 col14" >312</td>
#       <td id="T_0ed22_row2_col15" class="data row2 col15" >Sci-Fi & Fantasy</td>
#       <td id="T_0ed22_row2_col16" class="data row2 col16" >contenido_largo</td>
#     </tr>
#     <tr>
#       <th id="T_0ed22_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0ed22_row3_col0" class="data row3 col0" >s718</td>
#       <td id="T_0ed22_row3_col1" class="data row3 col1" >Movie</td>
#       <td id="T_0ed22_row3_col2" class="data row3 col2" >Headspace: Unwind Your Mind</td>
#       <td id="T_0ed22_row3_col3" class="data row3 col3" >nan</td>
#       <td id="T_0ed22_row3_col4" class="data row3 col4" >Andy Puddicombe, Evelyn Lewis Prieto, Ginger Daniels, Darren Pettie, Simon Prebble, Rhiannon Mcgavin, Kate Seftel</td>
#       <td id="T_0ed22_row3_col5" class="data row3 col5" >nan</td>
#       <td id="T_0ed22_row3_col6" class="data row3 col6" >2021-06-15 00:00:00</td>
#       <td id="T_0ed22_row3_col7" class="data row3 col7" >2021</td>
#       <td id="T_0ed22_row3_col8" class="data row3 col8" >TV-G</td>
#       <td id="T_0ed22_row3_col9" class="data row3 col9" >273 min</td>
#       <td id="T_0ed22_row3_col10" class="data row3 col10" >Documentaries</td>
#       <td id="T_0ed22_row3_col11" class="data row3 col11" >Do you want to relax, meditate or sleep deeply? Personalize the experience according to your mood or mindset with this Headspace interactive special.</td>
#       <td id="T_0ed22_row3_col12" class="data row3 col12" >2021</td>

# %% [markdown]
# ### Pregunta Desafío
#
# 11. ¿Cuáles son las combinaciones más frecuentes de género y rating en el dataset?
#     (Sugerencia: utilizar `value_counts` con `subset=["genre", "rating"]` después de aplicar `explode()`).
#
#
#
# ### Bonus: Análisis de duplicados y limpieza
#
# 12. ¿Existen películas con el mismo nombre (`title`) pero con distinto año de lanzamiento (`release_year`)?
# 13. ¿Cuántos títulos únicos hay en total en la columna `title`?

# %% [markdown]
# #### 11.¿Cuáles son las combinaciones más frecuentes de género y rating en el dataset?

# %%
combinaciones_genero_rating = df[['generos', 'rating']].value_counts().head(10)
display(combinaciones_genero_rating)
# Out:
# generos                 rating
# International Movies    TV-MA     1130
#                         TV-14     1065
# Dramas                  TV-MA      830
# International TV Shows  TV-MA      714
# Dramas                  TV-14      693
# International TV Shows  TV-14      472
# Comedies                TV-14      465
# TV Dramas               TV-MA      434
# Comedies                TV-MA      431
# Dramas                  R          375
# Name: count, dtype: int64
